# %% [markdown]
# # GeoGram: filtrace obcí končících na -ice
#
# Tento notebook ukazuje první krok: načtení seznamu obcí a výběr názvů končících na `-ice`.

# %%
from pathlib import Path
import pandas as pd
from geogram.data import load_municipalities, filter_suffix_ice

data_path = Path("..ata/raw/municipalities.csv")
df = load_municipalities(data_path)
df_ice = filter_suffix_ice(df, name_column="name")

print(f"Total rows: {len(df):,}")
print(f"-ice rows: {len(df_ice):,}")
df_ice.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 6
#       2 import pandas as pd
#       3 from geogram.data import load_municipalities, filter_suffix_ice
#       4
#       5 data_path = Path("..ata/raw/municipalities.csv")
# ----> 6 df = load_municipalities(data_path)
#       7 df_ice = filter_suffix_ice(df, name_column="name")
#       8
#       9 print(f"Total rows: {len(df):,}")
#
# File ~\Documents\UniversityCodingProject\NewFunnyProjects\GeoGram_sufix-ice\src\geogram\data.py:24, in load_municipalities(path, encoding, **kwargs)
#      22 def load_municipalities(path: Path, encoding: str = "utf-8", **kwargs) -> pd.DataFrame:
#      23     """Load municipality metadata from a CSV file and normalize the name column."""
# ---> 24     df = pd.read_csv(path, encoding=encoding, **kwargs)
#      25     if "name" not in df.columns:
#      26         name_column = infer_name_column(df.columns)
#
# File c:\Users\dobes\Documents\UniversityCodingProject\NewFunnyProjects\GeoGram_sufix-ice\.venv\Lib\site-packages\pandas\io\parsers\readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     861 kwds_defaults = _refine_defaults_read(
#     862     dialect,
#     863     delimiter,
#    (...)    869     dtype_backend=dtype_backend,
#     870 )
#     871 kwds.update(kwds_defaults)
# --> 873 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\dobes\Documents\UniversityCodingProject\NewFunnyProjects\GeoGram_sufix-ice\.venv\Lib\site-packages\pandas\io\parsers\readers.py:300, in _read(filepath_or_buffer, kwds)
#     297 _validate_names(kwds.get("names", None))
#     299 # Create the parser.
# --> 300 parser = TextFileReader(filepath_or_buffer, **kwds)
#     302 if chunksize or iterator:
#     303     return parser
#
# File c:\Users\dobes\Documents\UniversityCodingProject\NewFunnyProjects\GeoGram_sufix-ice\.venv\Lib\site-packages\pandas\io\parsers\readers.py:1645, in TextFileReader.__init__(self, f, engine, **kwds)
#    1642     self.options["has_index_names"] = kwds["has_index_names"]
#    1644 self.handles: IOHandles | None = None
# -> 1645 self._engine = self._make_engine(f, self.engine)
#
# File c:\Users\dobes\Documents\UniversityCodingProject\NewFunnyProjects\GeoGram_sufix-ice\.venv\Lib\site-packages\pandas\io\parsers\readers.py:1904, in TextFileReader._make_engine(self, f, engine)
#    1902     if "b" not in mode:
#    1903         mode += "b"
# -> 1904 self.handles = get_handle(
#    1905     f,
#    1906     mode,
#    1907     encoding=self.options.get("encoding", None),
#    1908     compression=self.options.get("compression", None),
#    1909     memory_map=self.options.get("memory_map", False),
#    1910     is_text=is_text,
#    1911     errors=self.options.get("encoding_errors", "strict"),
#    1912     storage_options=self.options.get("storage_options", None),
#    1913 )
#    1914 assert self.handles is not None
#    1915 f = self.handles.handle
#
# File c:\Users\dobes\Documents\UniversityCodingProject\NewFunnyProjects\GeoGram_sufix-ice\.venv\Lib\site-packages\pandas\io\common.py:939, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     930         handle = open(
#     931             handle,
#     932             ioargs.mode,
#    (...)    935             newline="",
#     936         )
#     937     else:
#     938         # Binary mode
# --> 939         handle = open(handle, ioargs.mode)
#     940     handles.append(handle)
#     942 # Convert BytesIO or file objects passed with an encoding
#
# FileNotFoundError: [Errno 2] No such file or directory: '..ata\\raw\\municipalities.csv'
