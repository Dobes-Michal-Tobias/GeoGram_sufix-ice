# %% [markdown]
# # GeoGram: projektové úvodní poznámky
#
# Tento notebook je pracovní prostor pro první průzkum dat a ověření pipeline.
#
# ## Cíle
#
# - získat seznam obcí v ČR
# - vyfiltrovat názvy končící na `-ice`
# - analyzovat gramatické číslo (singulár vs. plurál)
# - porovnat výsledky z IJP ÚJČ a Wikipedie
# - vytvořit mapu výsledků v ČR
